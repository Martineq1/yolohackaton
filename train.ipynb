# %%
from ultralytics import YOLO
import numpy as np
#from PIL import Image
#from io import BytesIO
#import cv2

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(data='C:\\Users\\marwl\\Desktop\\model\\dataset2\\data.yaml',
epochs=100,
imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.206 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200  Python-3.11.5 torch-2.1.0+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# ...

# %%
#trained_model.val()
